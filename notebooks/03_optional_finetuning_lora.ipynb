# %% [markdown]
# # 03 — Optional LoRA fine-tuning
# Squelette réservé à Gemma 4 / Unsloth ou MedGemma PEFT/QLoRA après validation de la baseline.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path('..').resolve()))  # racine du projet, pour importer src/
from src.inference import toy_predict
from src.guardrails import apply_safety_guardrails

# Placeholder : tant que le fine-tuning LoRA n'est pas branché (voir finetuning/*_stub.py),
# ce notebook se contente de rejouer la baseline jouet pour rester exécutable de bout en bout.
sample = Path('../data/sample_images/CXR_SYN_002_suspected_opacity.png')
apply_safety_guardrails(toy_predict(sample, mode='baseline'))
