# %% [markdown]
# # 01 — Baseline VLM
# Notebook de départ : charger une image, appliquer un prompt et sauvegarder une sortie JSON.

# %%
from pathlib import Path
import sys

# Ajout du répertoire racine au chemin Python
sys.path.append(str(Path('..').resolve()))
from src.inference import toy_predict
from src.guardrails import apply_safety_guardrails

# On teste sur une image synthétique dont le nom indique déjà la classe attendue
# (toy_predict lit le nom du fichier) : sert juste à vérifier que le pipeline tourne.
sample = Path('../data/sample_images/CXR_SYN_002_suspected_opacity.png')
apply_safety_guardrails(toy_predict(sample, mode='baseline'))
